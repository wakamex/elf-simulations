# %%
"""Script to query bot experiment data."""

# pylint: disable=invalid-name, wildcard-import, unused-wildcard-import, bare-except, wrong-import-position, redefined-outer-name, pointless-statement, missing-final-newline
# %%
# bot script setup
from script_functions import check_docker
check_docker(restart=True)
from script_setup import *
print("\n ==== Pool Config ===")
for k,v in config_data.items():
    print(f"{k:20} | {v}")
# Out:
# NAMES                         STATUS              PORTS
# infra_checkpoint-bot_1        Up About a minute
# infra_ethereum_1              Up About a minute   0.0.0.0:8546->8545/tcp
# infra_data_1                  Up About a minute
# infra_database-api-server_1   Up About a minute   0.0.0.0:5002->5002/tcp
# infra_artifacts_1             Up About a minute   80/tcp, 0.0.0.0:8080->8080/tcp
# infra_analysis_1              Up About a minute
# infra_db_1                    Up About a minute   0.0.0.0:5432->5432/tcp
# infra_dashboard_1             Up About a minute   0.0.0.0:5172->8501/tcp
#
# Found 8 running services, restarting docker...
# The UI_RPC_URL variable is not set. Defaulting to a blank string.
# The UI_ADDRESSES_URL variable is not set. Defaulting to a blank string.
# The UI_CHAIN_ID variable is not set. Defaulting to a blank string.
# The UI_ALCHEMY_GOERLI_RPC_KEY variable is not set. Defaulting to a blank string.
# The UI_WALLET_CONNECT_PROJECT_ID variable is not set. Defaulting to a blank string.
# Stopping infra_checkpoint-bot_1      ...
# Stopping infra_ethereum_1            ...
# Stopping infra_data_1                ...
# Stopping infra_database-api-server_1 ...
# Stopping infra_artifacts_1           ...
# Stopping infra_analysis_1            ...
# Stopping infra_db_1                  ...
# Stopping infra_dashboard_1           ...
# Stopping infra_artifacts_1           ... done
# Stopping infra_db_1                  ... done
# Stopping infra_analysis_1            ... done
# Stopping infra_checkpoint-bot_1      ... done
# Stopping infra_data_1                ... done
# Stopping infra_dashboard_1           ... done
# Stopping infra_database-api-server_1 ... done
# Stopping infra_ethereum_1            ... done
# Removing infra_mine_1                ...
# Removing infra_checkpoint-bot_1      ...
# Removing infra_ethereum_1            ...
# Removing infra_data_1                ...
# Removing infra_database-api-server_1 ...
# Removing infra_artifacts_1           ...
# Removing infra_analysis_1            ...
# Removing infra_db_1                  ...
# Removing infra_dashboard_1           ...
# Removing infra_analysis_1            ... done
# Removing infra_mine_1                ... done
# Removing infra_ethereum_1            ... done
# Removing infra_dashboard_1           ... done
# Removing infra_artifacts_1           ... done
# Removing infra_database-api-server_1 ... done
# Removing infra_data_1                ... done
# Removing infra_checkpoint-bot_1      ... done
# Removing infra_db_1                  ... done
# Removing network infra_default
# Removing volume infra_artifacts
# 0.7.0: Pulling from delvtech/elf-simulations/elf-simulations
# Digest: sha256:31353d6a2eec42651786b853c54a54669eac54dc8ecebf86f1d8363cbbb8e13f
# Status: Image is up to date for ghcr.io/delvtech/elf-simulations/elf-simulations:0.7.0
# ghcr.io/delvtech/elf-simulations/elf-simulations:0.7.0
# latest: Pulling from delvtech/elf-simulations/elf-simulations
# Digest: sha256:31353d6a2eec42651786b853c54a54669eac54dc8ecebf86f1d8363cbbb8e13f
# Status: Image is up to date for ghcr.io/delvtech/elf-simulations/elf-simulations:latest
# ghcr.io/delvtech/elf-simulations/elf-simulations:latest
# edge: Pulling from delvtech/elf-simulations/elf-simulations
# Digest: sha256:d239fd82b368e4447f4facfe2530a565746a623189a63b780f8764ad0ee90b2a
# Status: Image is up to date for ghcr.io/delvtech/elf-simulations/elf-simulations:edge
# ghcr.io/delvtech/elf-simulations/elf-simulations:edge
# 0.0.15: Pulling from delvtech/hyperdrive/devnet
# Digest: sha256:363c4d843e47c63e205a5bffe3c3c5d3f45e03fa717ee241e363fe68a3ef91cd
# Status: Image is up to date for ghcr.io/delvtech/hyperdrive/devnet:0.0.15
# ghcr.io/delvtech/hyperdrive/devnet:0.0.15
# 0.6.0: Pulling from delvtech/elf-simulations/elf-simulations
# Digest: sha256:c4f769e7ee2db849e1961fb1a9dadbefc8d565cd6d3f349ab1229c3be72cb74e
# Status: Image is up to date for ghcr.io/delvtech/elf-simulations/elf-simulations:0.6.0
# ghcr.io/delvtech/elf-simulations/elf-simulations:0.6.0
# 0.0.14: Pulling from delvtech/hyperdrive/devnet
# Digest: sha256:a608a65a8bf23a6d65071d2356316da94e737ffd8f0c487c441a80a4df6b54af
# Status: Image is up to date for ghcr.io/delvtech/hyperdrive/devnet:0.0.14
# ghcr.io/delvtech/hyperdrive/devnet:0.0.14
# 0.0.13: Pulling from delvtech/hyperdrive/devnet
# Digest: sha256:1e435089a00b42bfc66ea5d54874354c12a4b356a6fa9b803daf49af5a8c2a77
# Status: Image is up to date for ghcr.io/delvtech/hyperdrive/devnet:0.0.13
# ghcr.io/delvtech/hyperdrive/devnet:0.0.13
# 0.5.0: Pulling from delvtech/elf-simulations/elf-simulations
# Digest: sha256:3c4248f108b08e7e55c37bef051029b5cc1211179d5358571a069934b39f4193
# Status: Image is up to date for ghcr.io/delvtech/elf-simulations/elf-simulations:0.5.0
# ghcr.io/delvtech/elf-simulations/elf-simulations:0.5.0
# 0.0.4: Pulling from delvtech/infra/artifacts
# Digest: sha256:0f05028c5845c3ef171d35af960f3779c54e2e7aebfad8b6c98c4e178cdde1fe
# Status: Image is up to date for ghcr.io/delvtech/infra/artifacts:0.0.4
# ghcr.io/delvtech/infra/artifacts:0.0.4
# 0.0.11: Pulling from delvtech/hyperdrive/devnet
# Digest: sha256:2c04a62c9db7022aaf5557856f509c75f311f0e022d3f9dcdffa81375313b04c
# Status: Image is up to date for ghcr.io/delvtech/hyperdrive/devnet:0.0.11
# ghcr.io/delvtech/hyperdrive/devnet:0.0.11
# Shut down docker in 17.32s
# The UI_RPC_URL variable is not set. Defaulting to a blank string.
# The UI_ADDRESSES_URL variable is not set. Defaulting to a blank string.
# The UI_CHAIN_ID variable is not set. Defaulting to a blank string.
# The UI_ALCHEMY_GOERLI_RPC_KEY variable is not set. Defaulting to a blank string.
# The UI_WALLET_CONNECT_PROJECT_ID variable is not set. Defaulting to a blank string.
# Creating network "infra_default" with the default driver
# Creating volume "infra_artifacts" with default driver
# Creating infra_db_1 ...
# Creating infra_dashboard_1 ...
# Creating infra_database-api-server_1 ...
# Creating infra_data_1                ...
# Creating infra_analysis_1            ...
# Creating infra_artifacts_1           ...
# Creating infra_ethereum_1            ...
# Creating infra_db_1                  ... done
# Creating infra_data_1                ... done
# Creating infra_analysis_1            ... done
# Creating infra_artifacts_1           ... done
# Creating infra_dashboard_1           ... done
# Creating infra_ethereum_1            ... done
# Creating infra_mine_1                ...
# Creating infra_checkpoint-bot_1      ...
# Creating infra_database-api-server_1 ... done
# Creating infra_mine_1                ... done
# Creating infra_checkpoint-bot_1      ... done
# WARNING:root:No postgres connection, retrying
# Started docker in 1.66s
# Funding account 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5
# Added 1 agents
#
#  ==== Pool Config ===
# contractAddress      | 0xd8058efe0198ae9dD7D563e1b4938Dcbc86A1F81
# baseToken            | 0x5FbDB2315678afecb367f032d93F642f64180aa3
# initialSharePrice    | 1.000000000000000000
# minimumShareReserves | 10.000000000000000000
# minimumTransactionAmount | 0.001000000000000000
# positionDuration     | 604800
# checkpointDuration   | 3600
# timeStretch          | 0.044463125629060298
# governance           | 0xf39Fd6e51aad88F6F4ce6aB8827279cffFb92266
# feeCollector         | 0xf39Fd6e51aad88F6F4ce6aB8827279cffFb92266
# curveFee             | 0.100000000000000000
# flatFee              | 0.000500000000000000
# governanceFee        | 0.150000000000000000
# oracleSize           | 10
# updateGap            | 3600
# invTimeStretch       | 22.490546623794212364

# %%
logging.log(10, f" => SCRIPT: try {(n_trades:=108)} OPEN LONG")
run_trades(trade_list=[("open_long", 10_000)]*n_trades)
# Out:
#  => SCRIPT: try 108 OPEN LONG
# Funding account 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5
# Added 1 agents
# Block number: 9, Block time: 2023-10-11 11:22:44
# ACTION LOG 108/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 2000000000.0, post-trade = 1999990000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = None post-trade = 10008.586091019961602145 delta = 10008.586091019961602145
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 10, Block time: 2023-10-11 11:22:45
# ACTION LOG 107/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999990000.0, post-trade = 1999980000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 10008.586091019961602145 post-trade = 20017.092903940095771365 delta = 10008.50681292013416922
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 11, Block time: 2023-10-11 11:22:46
# ACTION LOG 106/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999980000.0, post-trade = 1999970000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 20017.092903940095771365 post-trade = 30025.520439926662410046 delta = 10008.427535986566638681
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 12, Block time: 2023-10-11 11:22:47
# ACTION LOG 105/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999970000.0, post-trade = 1999960000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 30025.520439926662410046 post-trade = 40033.86870014418432864 delta = 10008.348260217521918594
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 13, Block time: 2023-10-11 11:22:48
# ACTION LOG 104/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999960000.0, post-trade = 1999950000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 40033.86870014418432864 post-trade = 50042.137685755832663567 delta = 10008.268985611648334927
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 14, Block time: 2023-10-11 11:22:49
# ACTION LOG 103/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999950000.0, post-trade = 1999940000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 50042.137685755832663567 post-trade = 60050.327397923613833949 delta = 10008.189712167781170382
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 15, Block time: 2023-10-11 11:22:50
# ACTION LOG 102/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999940000.0, post-trade = 1999930000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 60050.327397923613833949 post-trade = 70058.437837807739394915 delta = 10008.110439884125560966
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 16, Block time: 2023-10-11 11:22:51
# ACTION LOG 101/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999930000.0, post-trade = 1999920000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 70058.437837807739394915 post-trade = 80066.469006566609004828 delta = 10008.031168758869609913
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 17, Block time: 2023-10-11 11:22:52
# ACTION LOG 100/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999920000.0, post-trade = 1999910000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 80066.469006566609004828 post-trade = 90074.420905357814137331 delta = 10007.951898791205132503
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 18, Block time: 2023-10-11 11:22:53
# ACTION LOG 99/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999910000.0, post-trade = 1999900000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 90074.420905357814137331 post-trade = 100082.293535336997627375 delta = 10007.872629979183490044
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 19, Block time: 2023-10-11 11:22:54
# ACTION LOG 98/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999900000.0, post-trade = 1999890000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 100082.293535336997627375 post-trade = 110090.086897658653193534 delta = 10007.793362321655566159
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 20, Block time: 2023-10-11 11:22:55
# ACTION LOG 97/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999890000.0, post-trade = 1999880000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 110090.086897658653193534 post-trade = 120097.800993475597610943 delta = 10007.714095816944417409
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 21, Block time: 2023-10-11 11:22:56
# ACTION LOG 96/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999880000.0, post-trade = 1999870000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 120097.800993475597610943 post-trade = 130105.435823939055647851 delta = 10007.634830463458036908
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 22, Block time: 2023-10-11 11:22:57
# ACTION LOG 95/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999870000.0, post-trade = 1999860000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 130105.435823939055647851 post-trade = 140112.991390199152904822 delta = 10007.555566260097256971
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 23, Block time: 2023-10-11 11:22:58
# ACTION LOG 94/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999860000.0, post-trade = 1999850000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 140112.991390199152904822 post-trade = 150120.467693403980145044 delta = 10007.476303204827240222
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 24, Block time: 2023-10-11 11:22:59
# ACTION LOG 93/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999850000.0, post-trade = 1999840000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 150120.467693403980145044 post-trade = 160127.864734700494371766 delta = 10007.397041296514226722
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 25, Block time: 2023-10-11 11:23:00
# ACTION LOG 92/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999840000.0, post-trade = 1999830000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 160127.864734700494371766 post-trade = 170135.182515234297322499 delta = 10007.317780533802950733
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 26, Block time: 2023-10-11 11:23:01
# ACTION LOG 91/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999830000.0, post-trade = 1999820000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 170135.182515234297322499 post-trade = 180142.421036149210059224 delta = 10007.238520914912736725
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 27, Block time: 2023-10-11 11:23:02
# ACTION LOG 90/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999820000.0, post-trade = 1999810000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 180142.421036149210059224 post-trade = 190149.580298587663768625 delta = 10007.159262438453709401
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 28, Block time: 2023-10-11 11:23:03
# ACTION LOG 89/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999810000.0, post-trade = 1999800000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 190149.580298587663768625 post-trade = 200156.660303690682324934 delta = 10007.080005103018556309
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 29, Block time: 2023-10-11 11:23:04
# ACTION LOG 88/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999800000.0, post-trade = 1999790000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 200156.660303690682324934 post-trade = 210163.661052598068905031 delta = 10007.000748907386580097
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 30, Block time: 2023-10-11 11:23:05
# ACTION LOG 87/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999790000.0, post-trade = 1999780000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 210163.661052598068905031 post-trade = 220170.582546447674726711 delta = 10006.92149384960582168
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 31, Block time: 2023-10-11 11:23:06
# ACTION LOG 86/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999780000.0, post-trade = 1999770000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 220170.582546447674726711 post-trade = 230177.424786375891674624 delta = 10006.842239928216947913
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 32, Block time: 2023-10-11 11:23:07
# ACTION LOG 85/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999770000.0, post-trade = 1999760000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 230177.424786375891674624 post-trade = 240184.187773518042702306 delta = 10006.762987142151027682
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 33, Block time: 2023-10-11 11:23:08
# ACTION LOG 84/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999760000.0, post-trade = 1999750000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 240184.187773518042702306 post-trade = 250190.87150900744686628 delta = 10006.683735489404163974
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 34, Block time: 2023-10-11 11:23:09
# ACTION LOG 83/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 51, Block time: 2023-10-11 11:23:26
# ACTION LOG 66/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999580000.0, post-trade = 1999570000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 420292.370600764487277402 post-trade = 430297.627998665292561214 delta = 10005.257397900805283812
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 52, Block time: 2023-10-11 11:23:27
# ACTION LOG 65/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999570000.0, post-trade = 1999560000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 430297.627998665292561214 post-trade = 440302.806166170848427574 delta = 10005.17816750555586636
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 53, Block time: 2023-10-11 11:23:28
# ACTION LOG 64/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999560000.0, post-trade = 1999550000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 440302.806166170848427574 post-trade = 450307.905104385108151246 delta = 10005.098938214259723672
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 54, Block time: 2023-10-11 11:23:29
# ACTION LOG 63/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999550000.0, post-trade = 1999540000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 450307.905104385108151246 post-trade = 460312.924814410571665498 delta = 10005.019710025463514252
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 55, Block time: 2023-10-11 11:23:30
# ACTION LOG 62/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999540000.0, post-trade = 1999530000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 460312.924814410571665498 post-trade = 470317.865297348268111798 delta = 10004.9404829376964463
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 56, Block time: 2023-10-11 11:23:31
# ACTION LOG 61/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999530000.0, post-trade = 1999520000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 470317.865297348268111798 post-trade = 480322.726554297636556518 delta = 10004.86125694936844472
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 57, Block time: 2023-10-11 11:23:32
# ACTION LOG 60/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999520000.0, post-trade = 1999510000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 480322.726554297636556518 post-trade = 490327.508586357220360092 delta = 10004.782032059583803574
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 58, Block time: 2023-10-11 11:23:33
# ACTION LOG 59/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999510000.0, post-trade = 1999500000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 490327.508586357220360092 post-trade = 500332.211394623327499477 delta = 10004.702808266107139385
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 59, Block time: 2023-10-11 11:23:34
# ACTION LOG 58/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999500000.0, post-trade = 1999490000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 500332.211394623327499477 post-trade = 510336.834980191335113592 delta = 10004.623585568007614115
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 60, Block time: 2023-10-11 11:23:35
# ACTION LOG 57/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999490000.0, post-trade = 1999480000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 510336.834980191335113592 post-trade = 520341.379344154655106141 delta = 10004.544363963319992549
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 61, Block time: 2023-10-11 11:23:36
# ACTION LOG 56/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999480000.0, post-trade = 1999470000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 520341.379344154655106141 post-trade = 530345.844487605834893872 delta = 10004.465143451179787731
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 62, Block time: 2023-10-11 11:23:37
# ACTION LOG 55/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999470000.0, post-trade = 1999460000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 530345.844487605834893872 post-trade = 540350.230411635624873398 delta = 10004.385924029789979526
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 63, Block time: 2023-10-11 11:23:38
# ACTION LOG 54/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999460000.0, post-trade = 1999450000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 540350.230411635624873398 post-trade = 550354.537117332859322998 delta = 10004.3067056972344496
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 64, Block time: 2023-10-11 11:23:39
# ACTION LOG 53/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999450000.0, post-trade = 1999440000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 550354.537117332859322998 post-trade = 560358.764605785556861144 delta = 10004.227488452697538146
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 65, Block time: 2023-10-11 11:23:40
# ACTION LOG 52/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999440000.0, post-trade = 1999430000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 560358.764605785556861144 post-trade = 570362.912878079886468752 delta = 10004.148272294329607608
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 66, Block time: 2023-10-11 11:23:41
# ACTION LOG 51/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999430000.0, post-trade = 1999420000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 570362.912878079886468752 post-trade = 580366.981935300759624807 delta = 10004.069057220873156055
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 67, Block time: 2023-10-11 11:23:42
# ACTION LOG 50/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999420000.0, post-trade = 1999410000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 580366.981935300759624807 post-trade = 590370.971778531609447521 delta = 10003.989843230849822714
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number:
.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 920458.204560291138386715 post-trade = 930459.501761915851290974 delta = 10001.297201624712904259
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 102, Block time: 2023-10-11 11:24:17
# ACTION LOG 15/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999070000.0, post-trade = 1999060000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 930459.501761915851290974 post-trade = 940460.719786538425158417 delta = 10001.218024622573867443
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 103, Block time: 2023-10-11 11:24:18
# ACTION LOG 14/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999060000.0, post-trade = 1999050000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 940460.719786538425158417 post-trade = 950461.858635189066229307 delta = 10001.13884865064107089
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 104, Block time: 2023-10-11 11:24:19
# ACTION LOG 13/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999050000.0, post-trade = 1999040000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 950461.858635189066229307 post-trade = 960462.918308896556331611 delta = 10001.059673707490102304
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 105, Block time: 2023-10-11 11:24:20
# ACTION LOG 12/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999040000.0, post-trade = 1999030000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 960462.918308896556331611 post-trade = 970463.89880868833618495 delta = 10000.980499791779853339
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 106, Block time: 2023-10-11 11:24:21
# ACTION LOG 11/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999030000.0, post-trade = 1999020000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 970463.89880868833618495 post-trade = 980464.800135589981541063 delta = 10000.901326901645356113
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 107, Block time: 2023-10-11 11:24:22
# ACTION LOG 10/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999020000.0, post-trade = 1999010000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 980464.800135589981541063 post-trade = 990465.622290625893787802 delta = 10000.822155035912246739
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 108, Block time: 2023-10-11 11:24:23
# ACTION LOG 9/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999010000.0, post-trade = 1999000000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 990465.622290625893787802 post-trade = 1000466.365274819281978084 delta = 10000.742984193388190282
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 109, Block time: 2023-10-11 11:24:24
# ACTION LOG 8/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1999000000.0, post-trade = 1998990000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 1000466.365274819281978084 post-trade = 1010467.029089191436568953 delta = 10000.663814372154590869
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 110, Block time: 2023-10-11 11:24:25
# ACTION LOG 7/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1998990000.0, post-trade = 1998980000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 1010467.029089191436568953 post-trade = 1020467.613734762217604557 delta = 10000.584645570781035604
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 111, Block time: 2023-10-11 11:24:26
# ACTION LOG 6/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1998980000.0, post-trade = 1998970000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 1020467.613734762217604557 post-trade = 1030468.119212550340243276 delta = 10000.505477788122638719
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 112, Block time: 2023-10-11 11:24:27
# ACTION LOG 5/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1998970000.0, post-trade = 1998960000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 1030468.119212550340243276 post-trade = 1040468.545523572446413342 delta = 10000.426311022106170066
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 113, Block time: 2023-10-11 11:24:28
# ACTION LOG 4/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1998960000.0, post-trade = 1998950000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 1040468.545523572446413342 post-trade = 1050468.892668844300803514 delta = 10000.347145271854390172
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 114, Block time: 2023-10-11 11:24:29
# ACTION LOG 3/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1998950000.0, post-trade = 1998940000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 1050468.892668844300803514 post-trade = 1060469.16064937996366462 delta = 10000.267980535662861106
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 115, Block time: 2023-10-11 11:24:30
# ACTION LOG 2/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1998940000.0, post-trade = 1998930000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 1060469.16064937996366462 post-trade = 1070469.34946619187416242 delta = 10000.1888168119104978
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 116, Block time: 2023-10-11 11:24:31
# ACTION LOG 1/108
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
#  => 💸base, pre-trade = 1998930000.0, post-trade = 1998920000.0, delta = -10000.0
#  => 🪘long-1697641200, pre-trade = 1070469.34946619187416242 post-trade = 1080469.459120291540131341 delta = 10000.109654099665968921
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.OPEN_LONG for 10000
# Block number: 117, Block time: 2023-10-11 11:24:32
# ACTION LOG 0/108

# %%
logging.log(10, " => SCRIPT: try 1 more OPEN LONG")
time.sleep(1)
run_trades(trade_list=[("open_long", 10_000)])
# Out:
#  => SCRIPT: try 1 more OPEN LONG
# Funding account 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5
# Added 1 agents
# Block number: 121, Block time: 2023-10-11 11:24:36
# ACTION LOG 1/1
# ContractCustomError NegativeInterest raised.
#  function name: openLong
# function args: (10000000000000000000000, 0, 0, '0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5', True)
# 🤖f56756 to perform HyperdriveActionType.OPEN_LONG for 10000
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) attempted HyperdriveActionType.OPEN_LONG for 10000
# Crashed with error: ('0x512095c7', "ContractCustomError NegativeInterest raised.\nfunction name: openLong\nfunction args: (10000000000000000000000, 0, 0, '0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5', True)")
# Pool can't open any more longs.
# Block number: 121, Block time: 2023-10-11 11:24:36
# ACTION LOG 0/1

# %%
logging.log(10, f" => SCRIPT: try {n_trades} CLOSE LONG")
time.sleep(1)
run_trades(trade_list=[("close_long", 10_000)]*(n_trades))
# Out:
#  => SCRIPT: try 108 CLOSE LONG
# Funding account 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5
# Added 1 agents
# Block number: 125, Block time: 2023-10-11 11:24:40
# ACTION LOG 108/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3998920000.0, post-trade = 3998929999.865003, delta = 9999.865003136218
#  => 🪘long-1697641200, pre-trade = 1080469.459120291540131341 post-trade = 1070469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 126, Block time: 2023-10-11 11:24:41
# ACTION LOG 107/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3998929999.865003, post-trade = 3998939999.6332564, delta = 9999.768253451279
#  => 🪘long-1697641200, pre-trade = 1070469.459120291540131341 post-trade = 1060469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 127, Block time: 2023-10-11 11:24:42
# ACTION LOG 106/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3998939999.6332564, post-trade = 3998949999.304762, delta = 9999.671505083677
#  => 🪘long-1697641200, pre-trade = 1060469.459120291540131341 post-trade = 1050469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 128, Block time: 2023-10-11 11:24:43
# ACTION LOG 105/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3998949999.304762, post-trade = 3998959998.87952, delta = 9999.574758031775
#  => 🪘long-1697641200, pre-trade = 1050469.459120291540131341 post-trade = 1040469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 129, Block time: 2023-10-11 11:24:44
# ACTION LOG 104/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3998959998.87952, post-trade = 3998969998.357532, delta = 9999.47801229332
#  => 🪘long-1697641200, pre-trade = 1040469.459120291540131341 post-trade = 1030469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 130, Block time: 2023-10-11 11:24:45
# ACTION LOG 103/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3998969998.357532, post-trade = 3998979997.7388, delta = 9999.381267867268
#  => 🪘long-1697641200, pre-trade = 1030469.459120291540131341 post-trade = 1020469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 131, Block time: 2023-10-11 11:24:46
# ACTION LOG 102/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3998979997.7388, post-trade = 3998989997.0233245, delta = 9999.284524751134
#  => 🪘long-1697641200, pre-trade = 1020469.459120291540131341 post-trade = 1010469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 132, Block time: 2023-10-11 11:24:47
# ACTION LOG 101/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3998989997.0233245, post-trade = 3998999996.2111077, delta = 9999.187782943633
#  => 🪘long-1697641200, pre-trade = 1010469.459120291540131341 post-trade = 1000469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 133, Block time: 2023-10-11 11:24:48
# ACTION LOG 100/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3998999996.2111077, post-trade = 3999009995.3021502, delta = 9999.091042442651
#  => 🪘long-1697641200, pre-trade = 1000469.459120291540131341 post-trade = 990469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 134, Block time: 2023-10-11 11:24:49
# ACTION LOG 99/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3
108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999299926.8660727, post-trade = 3999309923.0554986, delta = 9996.189426186802
#  => 🪘long-1697641200, pre-trade = 700469.459120291540131341 post-trade = 690469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 164, Block time: 2023-10-11 11:25:19
# ACTION LOG 69/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999309923.0554986, post-trade = 3999319919.148224, delta = 9996.092725309945
#  => 🪘long-1697641200, pre-trade = 690469.459120291540131341 post-trade = 680469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 165, Block time: 2023-10-11 11:25:20
# ACTION LOG 68/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999319919.148224, post-trade = 3999329915.1442494, delta = 9995.9960256829
#  => 🪘long-1697641200, pre-trade = 680469.459120291540131341 post-trade = 670469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 166, Block time: 2023-10-11 11:25:21
# ACTION LOG 67/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999329915.1442494, post-trade = 3999339911.0435767, delta = 9995.899327304096
#  => 🪘long-1697641200, pre-trade = 670469.459120291540131341 post-trade = 660469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 167, Block time: 2023-10-11 11:25:22
# ACTION LOG 66/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999339911.0435767, post-trade = 3999349906.846207, delta = 9995.802630171445
#  => 🪘long-1697641200, pre-trade = 660469.459120291540131341 post-trade = 650469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 168, Block time: 2023-10-11 11:25:23
# ACTION LOG 65/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999349906.846207, post-trade = 3999359902.552141, delta = 9995.705934283045
#  => 🪘long-1697641200, pre-trade = 650469.459120291540131341 post-trade = 640469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 169, Block time: 2023-10-11 11:25:24
# ACTION LOG 64/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999359902.552141, post-trade = 3999369898.161381, delta = 9995.609239637579
#  => 🪘long-1697641200, pre-trade = 640469.459120291540131341 post-trade = 630469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 170, Block time: 2023-10-11 11:25:25
# ACTION LOG 63/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999369898.161381, post-trade = 3999379893.6739273, delta = 9995.512546232903
#  => 🪘long-1697641200, pre-trade = 630469.459120291540131341 post-trade = 620469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 171, Block time: 2023-10-11 11:25:26
# ACTION LOG 62/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999379893.6739273, post-trade = 3999389889.0897813, delta = 9995.415854067369
#  => 🪘long-1697641200, pre-trade = 620469.459120291540131341 post-trade = 610469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 172, Block time: 2023-10-11 11:25:27
# ACTION LOG 61/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999389889.0897813, post-trade = 3999399884.4089446, delta = 9995.3191631391
#  => 🪘long-1697641200, pre-trade = 610469.459120291540131341 post-trade = 600469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 173, Block time: 2023-10-11 11:25:28
# ACTION LOG 60/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999399884.4089446, post-trade = 3999409879.6314178, delta = 9995.222473446509
#  => 🪘long-1697641200, pre-trade = 600469.459120291540131341 post-trade = 590469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 174, Block time: 2023-10-11 11:25:29
# ACTION LOG 59/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999409879.6314178, post-trade = 3999419874.757203, delta = 9995.12578498769
#  => 🪘long-1697641200, pre-trade = 590469.459120291540131341 post-trade = 580469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 175, Block time: 2023-10-11 11:25:30
# ACTION LOG 58/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999419874.757203, post-trade = 3999429869.7863007, delta = 9995.02909776082
#  => 🪘long-1697641200, pre-trade = 580469.459120291540131341 post-trade = 570469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 176, Block time: 2023-10-11 11:25:31
# ACTION LOG 57/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999429869.7863007, post-trade = 3999439864.7187123, delta = 9994.932411764257
#  => 🪘long-1697641200, pre-trade = 570469.459120291540131341 post-trade = 560469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 177, Block time: 2023-10-11 11:25:32
# ACTION LOG 56/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999439864.7187123, post-trade = 3999449859.5544395, delta = 9994.835726995943
#  => 🪘long-1697641200, pre-trade = 560469.459120291540131341 post-trade = 550469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 178, Block time: 2023-10-11 11:25:33
# ACTION LOG 55/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999449859.5544395, post-trade = 3999459854.293483, delta = 9994.739043454707
#  => 🪘long-1697641200, pre-trade = 550469.459120291540131341 post-trade = 540469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 179, Block time: 2023-10-11 11:25:34
# ACTION LOG 54/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999459854.293483, post-trade = 3999469848.935844, delta = 9994.642361138154
#  => 🪘long-1697641200, pre-trade = 540469.459120291540131341 post-trade = 530469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 180, Block time: 2023-10-11 11:25:35
# ACTION LOG 53/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999469848.935844, post-trade = 3999479843.481524, delta = 9994.545680044774
#  => 🪘long-1697641200, pre-trade = 530469.459120291540131341 post-trade = 520469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 181, Block time: 2023-10-11 11:25:36
# ACTION LOG 52/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999479843.481524, post-trade = 3999489837.9305243, delta = 9994.44900017284
#  => 🪘long-1697641200, pre-trade = 520469.459120291540131341 post-trade = 510469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 182, Block time: 2023-10-11 11:25:37
# ACTION LOG 51/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999489837.9305243, post-trade = 3999499832.2828455, delta = 9994.35232152021
#  => 🪘long-1697641200, pre-trade = 510469.459120291540131341 post-trade = 500469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 183, Block time: 2023-10-11 11:25:38
# ACTION LOG 50/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999499832.2828455, post-trade = 3999509826.53849, delta = 9994.255644085923
#  => 🪘long-1697641200, pre-trade = 500469.459120291540131341 post-trade = 490469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 184, Block time: 2023-10-11 11:25:39
# ACTION LOG 49/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999509826.53849, post-trade = 3999519820.697458, delta = 9994.158967867197
#  => 🪘long-1697641200, pre-trade = 490469.459120291540131341 post-trade = 480469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 185, Block time: 2023-10-11 11:25:40
# ACTION LOG 48/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999519820.697458, post-trade = 3999529814.7597504, delta = 9994.06229286304
#  => 🪘long-1697641200, pre-trade = 480469.459120291540131341 post-trade = 470469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 186, Block time: 2023-10-11 11:25:41
# ACTION LOG 47/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999529814.7597504, post-trade = 3999539808.7253695, delta = 9993.96561907154
#  => 🪘long-1697641200, pre-trade = 470469.459120291540131341 post-trade = 460469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 187, Block time: 2023-10-11 11:25:42
# ACTION LOG 46/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999539808.7253695, post-trade = 3999549802.594316, delta = 9993.868946490362
#  => 🪘long-1697641200, pre-trade = 460469.459120291540131341 post-trade = 450469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 188, Block time: 2023-10-11 11:25:43
# ACTION LOG 45/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999549802.594316, post-trade = 3999559796.3665915, delta = 9993.772275118361
#  => 🪘long-1697641200, pre-trade = 450469.459120291540131341 post-trade = 440469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 189, Block time: 2023-10-11 11:25:44
# ACTION LOG 44/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999559796.3665915, post-trade = 3999569790.0421963, delta = 9993.675604953474
#  => 🪘long-1697641200, pre-trade = 440469.459120291540131341 post-trade = 430469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 190, Block time: 2023-10-11 11:25:45
# ACTION LOG 43/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999569790.0421963, post-trade = 3999579783.6211324, delta = 9993.578935994015
#  => 🪘long-1697641200, pre-trade = 430469.459120291540131341 post-trade = 420469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 191, Block time: 2023-10-11 11:25:46
# ACTION LOG 42/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999579783.6211324, post-trade = 3999589777.1034, delta = 9993.48226823839
#  => 🪘long-1697641200, pre-trade = 420469.459120291540131341 post-trade = 410469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 192, Block time: 2023-10-11 11:25:47
# ACTION LOG 41/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999589777.1034, post-trade = 3999599770.489002, delta = 9993.385601684276
#  => 🪘long-1697641200, pre-trade = 410469.459120291540131341 post-trade = 400469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 193, Block time: 2023-10-11 11:25:48
# ACTION LOG 40/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999599770.489002, post-trade = 3999609763.7779384, delta = 9993.288936330544
#  => 🪘long-1697641200, pre-trade = 400469.459120291540131341 post-trade = 390469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 194, Block time: 2023-10-11 11:25:49
# ACTION LOG 39/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999609763.7779384, post-trade = 3999619756.9702106, delta = 9993.192272175138
#  => 🪘long-1697641200, pre-trade = 390469.459120291540131341 post-trade = 380469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 195, Block time: 2023-10-11 11:25:50
# ACTION LOG 38/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999619756.9702106, post-trade = 3999629750.0658197, delta = 9993.095609215992
#  => 🪘long-1697641200, pre-trade = 380469.459120291540131341 post-trade = 370469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 196, Block time: 2023-10-11 11:25:51
# ACTION LOG 37/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999629750.0658197, post-trade = 3999639743.0647674, delta = 9992.99894745202
#  => 🪘long-1697641200, pre-trade = 370469.459120291540131341 post-trade = 360469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 197, Block time: 2023-10-11 11:25:52
# ACTION LOG 36/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999639743.0647674, post-trade = 3999649735.9670544, delta = 9992.902286880817
#  => 🪘long-1697641200, pre-trade = 360469.459120291540131341 post-trade = 350469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 198, Block time: 2023-10-11 11:25:53
# ACTION LOG 35/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999649735.9670544, post-trade = 3999659728.7726817, delta = 9992.805627500662
#  => 🪘long-1697641200, pre-trade = 350469.459120291540131341 post-trade = 340469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 199, Block time: 2023-10-11 11:25:54
# ACTION LOG 34/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999659728.7726817, post-trade = 3999669721.481651, delta = 9992.70896931042
#  => 🪘long-1697641200, pre-trade = 340469.459120291540131341 post-trade = 330469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 200, Block time: 2023-10-11 11:25:55
# ACTION LOG 33/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999669721.481651, post-trade = 3999679714.093963, delta = 9992.61231230753
#  => 🪘long-1697641200, pre-trade = 330469.459120291540131341 post-trade = 320469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 201, Block time: 2023-10-11 11:25:56
# ACTION LOG 32/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999679714.093963, post-trade = 3999689706.6096196, delta = 9992.515656490825
#  => 🪘long-1697641200, pre-trade = 320469.459120291540131341 post-trade = 310469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 202, Block time: 2023-10-11 11:25:57
# ACTION LOG 31/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999689706.6096196, post-trade = 3999699699.0286217, delta = 9992.419001857907
#  => 🪘long-1697641200, pre-trade = 310469.459120291540131341 post-trade = 300469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 203, Block time: 2023-10-11 11:25:58
# ACTION LOG 30/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999699699.0286217, post-trade = 3999709691.35097, delta = 9992.322348407573
#  => 🪘long-1697641200, pre-trade = 300469.459120291540131341 post-trade = 290469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 204, Block time: 2023-10-11 11:25:59
# ACTION LOG 29/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999709691.35097, post-trade = 3999719683.5766664, delta = 9992.225696137899
#  => 🪘long-1697641200, pre-trade = 290469.459120291540131341 post-trade = 280469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 205, Block time: 2023-10-11 11:26:00
# ACTION LOG 28/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999719683.5766664, post-trade = 3999729675.7057114, delta = 9992.129045047039
#  => 🪘long-1697641200, pre-trade = 280469.459120291540131341 post-trade = 270469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 206, Block time: 2023-10-11 11:26:01
# ACTION LOG 27/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999729675.7057114, post-trade = 3999739667.7381063, delta = 9992.032395133032
#  => 🪘long-1697641200, pre-trade = 270469.459120291540131341 post-trade = 260469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 207, Block time: 2023-10-11 11:26:02
# ACTION LOG 26/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999739667.7381063, post-trade = 3999749659.673853, delta = 9991.935746394704
#  => 🪘long-1697641200, pre-trade = 260469.459120291540131341 post-trade = 250469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 208, Block time: 2023-10-11 11:26:03
# ACTION LOG 25/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999749659.673853, post-trade = 3999759651.5129514, delta = 9991.839098829456
#  => 🪘long-1697641200, pre-trade = 250469.459120291540131341 post-trade = 240469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 209, Block time: 2023-10-11 11:26:04
# ACTION LOG 24/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999759651.5129514, post-trade = 3999769643.255404, delta = 9991.742452436178
#  => 🪘long-1697641200, pre-trade = 240469.459120291540131341 post-trade = 230469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 210, Block time: 2023-10-11 11:26:05
# ACTION LOG 23/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999769643.255404, post-trade = 3999779634.9012113, delta = 9991.645807212939
#  => 🪘long-1697641200, pre-trade = 230469.459120291540131341 post-trade = 220469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 211, Block time: 2023-10-11 11:26:06
# ACTION LOG 22/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999779634.9012113, post-trade = 3999789626.4503746, delta = 9991.549163157792
#  => 🪘long-1697641200, pre-trade = 220469.459120291540131341 post-trade = 210469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 212, Block time: 2023-10-11 11:26:07
# ACTION LOG 21/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999789626.4503746, post-trade = 3999799617.9028945, delta = 9991.452520268971
#  => 🪘long-1697641200, pre-trade = 210469.459120291540131341 post-trade = 200469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 213, Block time: 2023-10-11 11:26:08
# ACTION LOG 20/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999799617.9028945, post-trade = 3999809609.2587733, delta = 9991.355878545195
#  => 🪘long-1697641200, pre-trade = 200469.459120291540131341 post-trade = 190469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 214, Block time: 2023-10-11 11:26:09
# ACTION LOG 19/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999809609.2587733, post-trade = 3999819600.518011, delta = 9991.25923798386
#  => 🪘long-1697641200, pre-trade = 190469.459120291540131341 post-trade = 180469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 215, Block time: 2023-10-11 11:26:10
# ACTION LOG 18/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999819600.518011, post-trade = 3999829591.6806097, delta = 9991.162598583855
#  => 🪘long-1697641200, pre-trade = 180469.459120291540131341 post-trade = 170469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 216, Block time: 2023-10-11 11:26:11
# ACTION LOG 17/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999829591.6806097, post-trade = 3999839582.74657, delta = 9991.065960343438
#  => 🪘long-1697641200, pre-trade = 170469.459120291540131341 post-trade = 160469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 217, Block time: 2023-10-11 11:26:12
# ACTION LOG 16/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999839582.74657, post-trade = 3999849573.7158933, delta = 9990.96932326036
#  => 🪘long-1697641200, pre-trade = 160469.459120291540131341 post-trade = 150469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 218, Block time: 2023-10-11 11:26:13
# ACTION LOG 15/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999849573.7158933, post-trade = 3999859564.5885806, delta = 9990.87268733285
#  => 🪘long-1697641200, pre-trade = 150469.459120291540131341 post-trade = 140469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 219, Block time: 2023-10-11 11:26:14
# ACTION LOG 14/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999859564.5885806, post-trade = 3999869555.364633, delta = 9990.776052559822
#  => 🪘long-1697641200, pre-trade = 140469.459120291540131341 post-trade = 130469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 220, Block time: 2023-10-11 11:26:15
# ACTION LOG 13/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999869555.364633, post-trade = 3999879546.044052, delta = 9990.67941893887
#  => 🪘long-1697641200, pre-trade = 130469.459120291540131341 post-trade = 120469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 221, Block time: 2023-10-11 11:26:16
# ACTION LOG 12/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999879546.044052, post-trade = 3999889536.6268387, delta = 9990.582786468467
#  => 🪘long-1697641200, pre-trade = 120469.459120291540131341 post-trade = 110469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 222, Block time: 2023-10-11 11:26:17
# ACTION LOG 11/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999889536.6268387, post-trade = 3999899527.1129937, delta = 9990.486155146778
#  => 🪘long-1697641200, pre-trade = 110469.459120291540131341 post-trade = 100469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 223, Block time: 2023-10-11 11:26:18
# ACTION LOG 10/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999899527.1129937, post-trade = 3999909517.5025187, delta = 9990.38952497204
#  => 🪘long-1697641200, pre-trade = 100469.459120291540131341 post-trade = 90469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 224, Block time: 2023-10-11 11:26:19
# ACTION LOG 9/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999909517.5025187, post-trade = 3999919507.795415, delta = 9990.292895942484
#  => 🪘long-1697641200, pre-trade = 90469.459120291540131341 post-trade = 80469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 225, Block time: 2023-10-11 11:26:20
# ACTION LOG 8/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999919507.795415, post-trade = 3999929497.991683, delta = 9990.196268056312
#  => 🪘long-1697641200, pre-trade = 80469.459120291540131341 post-trade = 70469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 226, Block time: 2023-10-11 11:26:21
# ACTION LOG 7/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999929497.991683, post-trade = 3999939488.091324, delta = 9990.099641312012
#  => 🪘long-1697641200, pre-trade = 70469.459120291540131341 post-trade = 60469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 227, Block time: 2023-10-11 11:26:22
# ACTION LOG 6/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999939488.091324, post-trade = 3999949478.09434, delta = 9990.00301570736
#  => 🪘long-1697641200, pre-trade = 60469.459120291540131341 post-trade = 50469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 228, Block time: 2023-10-11 11:26:23
# ACTION LOG 5/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999949478.09434, post-trade = 3999959468.000731, delta = 9989.906391241006
#  => 🪘long-1697641200, pre-trade = 50469.459120291540131341 post-trade = 40469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 229, Block time: 2023-10-11 11:26:24
# ACTION LOG 4/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999959468.000731, post-trade = 3999969457.8104987, delta = 9989.809767910889
#  => 🪘long-1697641200, pre-trade = 40469.459120291540131341 post-trade = 30469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 230, Block time: 2023-10-11 11:26:25
# ACTION LOG 3/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999969457.8104987, post-trade = 3999979447.5236444, delta = 9989.713145715226
#  => 🪘long-1697641200, pre-trade = 30469.459120291540131341 post-trade = 20469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 231, Block time: 2023-10-11 11:26:26
# ACTION LOG 2/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999979447.5236444, post-trade = 3999989437.140169, delta = 9989.616524652618
#  => 🪘long-1697641200, pre-trade = 20469.459120291540131341 post-trade = 10469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 232, Block time: 2023-10-11 11:26:27
# ACTION LOG 1/108
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
#  => 💸base, pre-trade = 3999989437.140169, post-trade = 3999999426.660074, delta = 9989.51990472095
#  => 🪘long-1697641200, pre-trade = 10469.459120291540131341 post-trade = 469.459120291540131341 delta = -10000.0
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) performed HyperdriveActionType.CLOSE_LONG for 10000
# Block number: 233, Block time: 2023-10-11 11:26:28
# ACTION LOG 0/108

# %%
logging.log(10, " => SCRIPT: try 1 more CLOSE LONG")
time.sleep(1)
try:
    run_trades(trade_list=[("close_long", 10_000)])
except Exception as exc:
    print("Cannot close another short.")
# Out:
#  => SCRIPT: try 1 more CLOSE LONG
# Funding account 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5
# Added 1 agents
# Block number: 237, Block time: 2023-10-11 11:26:32
# ACTION LOG 1/1
# ContractLogicError:
# Panic error 0x11: Arithmetic operation results in underflow or overflow.
# function name:closeLong
# function args: (1697641200, 10000000000000000000000, 0, '0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5', True)
# 🤖f56756 to perform HyperdriveActionType.CLOSE_LONG for 10000
# AGENT 0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5 (DBot) attempted HyperdriveActionType.CLOSE_LONG for 10000
# Crashed with error: ('Panic error 0x11: Arithmetic operation results in underflow or overflow.', "ContractLogicError raised.\nfunction name: closeLong\nfunction args: (1697641200, 10000000000000000000000, 0, '0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5', True)")
# Exception: ('Panic error 0x11: Arithmetic operation results in underflow or overflow.', "ContractLogicError raised.\nfunction name: closeLong\nfunction args: (1697641200, 10000000000000000000000, 0, '0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5', True)")
# Trade: {
#     "market_type": "HYPERDRIVE",
#     "action_type": "CLOSE_LONG",
#     "trade_amount": "10000.0",
#     "slippage_tolerance": null,
#     "maturity_time": 1697641200
# }
# Wallet: {
#     "base": "4999999426.660074045308632094",
#     "longs": [
#         {
#             "maturity_time": 1697641200,
#             "balance": "469.459120291540131341"
#         }
#     ],
#     "shorts": [],
#     "lp_tokens": "0.0",
#     "withdraw_shares": "0.0"
# }
# PoolInfo: {
#     "shareReserves": "100000557.738268538631639494",
#     "shareAdjustment": "-7.75148761362025676",
#     "bondReserves": "102178517.83267775757407005",
#     "lpTotalSupply": "99999990.0",
#     "sharePrice": "1.000265904141804773",
#     "longsOutstanding": "469.459120291540131341",
#     "longAverageMaturityTime": "1697641200.0",
#     "shortsOutstanding": "0.0",
#     "shortAverageMaturityTime": "0.0",
#     "withdrawalSharesReadyToWithdraw": "0.0",
#     "withdrawalSharesProceeds": "0.0",
#     "lpSharePrice": "1.000266792912590012",
#     "longExposure": "365.723234043070130668",
#     "timestamp": "2023-10-11 15:26:32",
#     "blockNumber": 237,
#     "totalSupplyWithdrawalShares": 0
# }
# PoolConfig: {
#     "baseToken": "0x5FbDB2315678afecb367f032d93F642f64180aa3",
#     "initialSharePrice": "1.0",
#     "minimumShareReserves": "10.0",
#     "minimumTransactionAmount": "0.001",
#     "positionDuration": 604800,
#     "checkpointDuration": 3600,
#     "timeStretch": "0.044463125629060298",
#     "governance": "0xf39Fd6e51aad88F6F4ce6aB8827279cffFb92266",
#     "feeCollector": "0xf39Fd6e51aad88F6F4ce6aB8827279cffFb92266",
#     "fees": [
#         "0.1",
#         "0.0005",
#         "0.15"
#     ],
#     "oracleSize": 10,
#     "updateGap": 3600,
#     "contractAddress": "0xd8058efe0198ae9dD7D563e1b4938Dcbc86A1F81",
#     "curveFee": "0.1",
#     "flatFee": "0.0005",
#     "governanceFee": "0.15",
#     "invTimeStretch": "22.490546623794212364"
# }
# Traceback:   File "/home/mihai/.pyenv/versions/3.10.11/lib/python3.10/asyncio/tasks.py", line 232, in __step
#     result = coro.send(None)
#   File "/code/mihaipy/lib/agent0/agent0/hyperdrive/exec/execute_agent_trades.py", line 198, in async_match_contract_call_to_trade
#     trade_result = await hyperdrive.async_close_long(
#   File "/code/mihaipy/lib/ethpy/ethpy/hyperdrive/api.py", line 382, in async_close_long
#     tx_receipt = await async_smart_contract_transact(
#   File "/code/mihaipy/lib/ethpy/ethpy/base/transactions.py", line 251, in async_smart_contract_transact
#     raise err
#   File "/code/mihaipy/lib/ethpy/ethpy/base/transactions.py", line 214, in async_smart_contract_transact
#     unsent_txn = func_handle.build_transaction(
#   File "/home/mihai/.pyenv/versions/3.10.11/envs/mihaipy/lib/python3.10/site-packages/web3/contract/contract.py", line 332, in build_transaction
#     return build_transaction_for_function(
#   File "/home/mihai/.pyenv/versions/3.10.11/envs/mihaipy/lib/python3.10/site-packages/web3/contract/utils.py", line 232, in build_transaction_for_function
#     prepared_transaction = fill_transaction_defaults(w3, prepared_transaction)
#   File "cytoolz/functoolz.pyx", line 263, in cytoolz.functoolz.curry.__call__
#   File "/home/mihai/.pyenv/versions/3.10.11/envs/mihaipy/lib/python3.10/site-packages/web3/_utils/transactions.py", line 132, in fill_transaction_defaults
#     default_val = default_getter(w3, transaction)
#   File "/home/mihai/.pyenv/versions/3.10.11/envs/mihaipy/lib/python3.10/site-packages/web3/_utils/transactions.py", line 72, in <lambda>
#     "gas": lambda w3, tx: w3.eth.estimate_gas(tx),
#   File "/home/mihai/.pyenv/versions/3.10.11/envs/mihaipy/lib/python3.10/site-packages/web3/eth/eth.py", line 293, in estimate_gas
#     return self._estimate_gas(transaction, block_identifier)
#   File "/home/mihai/.pyenv/versions/3.10.11/envs/mihaipy/lib/python3.10/site-packages/web3/module.py", line 73, in caller
#     result = w3.manager.request_blocking(
#   File "/home/mihai/.pyenv/versions/3.10.11/envs/mihaipy/lib/python3.10/site-packages/web3/manager.py", line 250, in request_blocking
#     return self.formatted_response(
#   File "/home/mihai/.pyenv/versions/3.10.11/envs/mihaipy/lib/python3.10/site-packages/web3/manager.py", line 209, in formatted_response
#     apply_error_formatters(error_formatters, response)
#   File "/home/mihai/.pyenv/versions/3.10.11/envs/mihaipy/lib/python3.10/site-packages/web3/manager.py", line 85, in apply_error_formatters
#     formatted_resp = pipe(response, error_formatters)
#   File "cytoolz/functoolz.pyx", line 680, in cytoolz.functoolz.pipe
#   File "cytoolz/functoolz.pyx", line 655, in cytoolz.functoolz.c_pipe
#   File "/home/mihai/.pyenv/versions/3.10.11/envs/mihaipy/lib/python3.10/site-packages/web3/_utils/contract_error_handling.py", line 126, in raise_contract_logic_error_on_revert
#     raise ContractPanicError(PANIC_ERROR_CODES[panic_error_code], data=data)
#
#
# Cannot close another short.

# %%
# get data
time.sleep(1)
data, pool_info = get_data(session, config_data)
print(data.iloc[0].T)
# Out:
# operator                              0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5
# from                                  0x0000000000000000000000000000000000000000
# to                                    0xf56756C55C02Cb2ba5eF3dBddFf8648EF0dbC4F5
# id                             4523128485832663883733241601901871400518358776...
# prefix                                                                         1
# maturity_time                                                         1697641200
# value                                                  10008586091019961892864.0
# bond_reserves                                       102168986.465411324800042227
# trade_type                                                              openLong
# long_exposure                                           10017.315879863927583117
# longs_outstanding                                       10008.586091019961602145
# longs_average_maturity_time                        1697641200.000000000000000000
# lp_total_supply                                      99999990.000000000000000000
# share_price                                                 1.000265544140030441
# share_reserves                                      100009997.201603873384117905
# share_adjustment                                                           0E-18
# short_average_maturity_time                                                0E-18
# shorts_outstanding                                                         0E-18
# block_timestamp                                              1697037765000000000
# transaction_hash               0xb9fd96bbedf935f2670736c1ced8e23fb46e407a33a7...
# transaction_index                                                              0
# trade_enum                                                                  LONG
# timestamp                                                    2023-10-11 15:22:45
# rate                                                                         NaN
# fixed_rate                                       0.04954068650638997877025802204
# spot_price                                                  0.999050806466712700
# base_buffer                                        10015.92907518848509004688287
# Name: 0, dtype: object

# %%
plot_reserves(data, include_buffer=True)
plt.savefig("reserves.png")
# Out:
# Index(['blockNumber', 'operator', 'from', 'to', 'id', 'prefix',
#        'maturity_time', 'value', 'bond_reserves', 'trade_type',
#        'long_exposure', 'longs_outstanding', 'longs_average_maturity_time',
#        'lp_total_supply', 'share_price', 'share_reserves', 'share_adjustment',
#        'short_average_maturity_time', 'shorts_outstanding', 'block_timestamp',
#        'transaction_hash', 'transaction_index', 'trade_enum', 'timestamp',
#        'rate', 'fixed_rate', 'spot_price', 'base_buffer'],
#       dtype='object')

# %%
plot_positions(data)
plt.savefig("positions.png")

# %%
ax1, lines1, labels1 = plot_rate_price(data)
plt.savefig("rate_price.png")

# %%
ax1, lines1, labels1, _data = plot_rate(data, legend=False)
plot_secondary(_data, "spot_price", ax1, lines1, labels1)
plt.savefig("rate_price2.png")

# %%
# plot reserves in zoom mode
ax1, lines1, labels1 = plot_reserves(data, include_buffer=True)
# ax1.set_ylim([0,1e8])
ax1.set_title(f"{ax1.get_title()} zoomed in")
plt.savefig("reserves_zoom.png")
# Out:
# Index(['blockNumber', 'operator', 'from', 'to', 'id', 'prefix',
#        'maturity_time', 'value', 'bond_reserves', 'trade_type',
#        'long_exposure', 'longs_outstanding', 'longs_average_maturity_time',
#        'lp_total_supply', 'share_price', 'share_reserves', 'share_adjustment',
#        'short_average_maturity_time', 'shorts_outstanding', 'block_timestamp',
#        'transaction_hash', 'transaction_index', 'trade_enum', 'timestamp',
#        'rate', 'fixed_rate', 'spot_price', 'base_buffer'],
#       dtype='object')

# %%
# plot individual graphs
# fig, axes = plt.subplots(2, 2, figsize=(10, 6))
# plt.tight_layout(pad=0, w_pad=3, h_pad=3)
# plot_positions(data, ax=axes[0,0])
# plot_reserves(data, ax=axes[0,1])
# plot_rate_price(data, ax=axes[1,0])
# plot_buffers(data, ax=axes[1,1])

# %%
# plot stuff
# fig, axes = plt.subplots(2, 2, figsize=(10, 6))
# plt.tight_layout(pad=0, w_pad=3, h_pad=3)
# ax1, lines1, labels1 = plot_positions(data, axes[0,0])
# plot_secondary(data, "fixed_rate", ax1, lines1, labels1)
# ax1, lines1, labels1 = plot_positions(data, axes[1,0])
# plot_secondary(data, "spot_price", ax1, lines1, labels1)
# ax1, lines1, labels1 = plot_reserves(data, axes[0,1])
# plot_secondary(data, "fixed_rate", ax1, lines1, labels1)
# ax1, lines1, labels1 = plot_reserves(data, axes[1,1])
# plot_secondary(data, "spot_price", ax1, lines1, labels1)
